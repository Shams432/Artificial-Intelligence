# %% [markdown]
# # N Queen Attack Detection

# %%
import matplotlib.pyplot as plt
def drawBoard(P):
  n = len(P)
  # Create a figure and axes
  fig, ax = plt.subplots()

  # Set axis limits and aspect ratio
  ax.set_xlim(0, n)
  ax.set_ylim(0, n)
  ax.set_aspect('equal')

  # Turn off axis ticks and labels
  ax.set_xticks([])
  ax.set_yticks([])

  # Draw the board grid
  for i in range(n + 1):
      ax.plot([0, n], [i, i], 'k-', linewidth=2) # Horizontal lines
      ax.plot([i, i], [0, n], 'k-', linewidth=2) # Vertical lines

  # Place queens
  for i in range(n):
    row, col = P[i]
    # Adjust for visual centering
    ax.text(col - 0.5 , n - row + 0.5, 'Q'+str(i + 1), ha='center', va='center', fontsize=12, color='red', weight='bold')

  # Show the plot
  plt.show()

# %%
import random
def generatePositions(n = 4):
  pos = []
  numbers  = random.sample(range(1,n*n), n)
  for v in numbers:
    pos.append((v//n+1,v%n+1))
  return pos

positions = generatePositions()
drawBoard(positions)

# %%
# row attack
def rowAttacK(P):
  count = 0
  for i, (rowi , _) in enumerate(P):
    for j in range(i+1,len(P)):
      if  rowi == P[j][0]:
        print(f'row attack:Q{i+1}{P[i]} and Q{j+1}{P[j]}')
        count += 1
  return count

rowAttacK(positions)
# Out:
# row attack:Q2(1, 3) and Q3(1, 4)
# 1

# %%
#column attack
def columnAttacK(P):
  count = 0
  for i, (columni , _) in enumerate(P):
    for j in range(i+1,len(P)):
      if  columni == P[j][1]:
        print(f'column attack:Q{i+1}{P[i]} and Q{j+1}{P[j]}')
        count += 1
  return count

columnAttacK(positions)
# Out:
# 0

# %%
# diagonal atack
def diagonalAttack(P):
  count = 0
  for i in range(len(P)):
    for j in range(i + 1, len(P)):
      row1, col1 = P[i]
      row2, col2 = P[j]
      if abs(row1 - row2) == abs(col1 - col2):
        print(f"Diagonal attack: Q{i + 1}{P[i]} and Q{j + 1}{P[j]}")
        count += 1
        return count

# %%
# implement a method to print a state is valid or not
def isValid(P):
  if rowAttacK(P) > 0 or columnAttacK(P) > 0 or diagonalAttack(P) > 0:
    return False
  else:
    return True
if isValid(positions):
  print("The state is valid.")
else:
  print("The state is invalid.")
# Out:
# row attack:Q2(1, 3) and Q3(1, 4)
# The state is invalid.

# %%
# call isValid untill you get valid solution
steps = 0
while(True):
  steps += 1
  pos = generatePositions(4)
  if isValid(pos):
    print(f'A solution was found at step {steps}')
    drawBoard(pos)
    break
  if steps >= 5:
    print(f'No solution was found in the first {steps} steps')
    break
# Out:
# column attack:Q1(3, 4) and Q4(2, 3)
# row attack:Q1(4, 1) and Q2(4, 4)
# row attack:Q1(4, 1) and Q3(4, 3)
# row attack:Q2(4, 4) and Q3(4, 3)
# row attack:Q1(3, 3) and Q2(3, 1)
# row attack:Q1(2, 2) and Q3(2, 3)
# row attack:Q1(2, 4) and Q2(2, 2)
# No solution was found in the first 5 steps
